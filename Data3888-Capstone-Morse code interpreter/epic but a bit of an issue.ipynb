# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("epic_output.csv")

# %%
df
# Out:
#      [1256.0965789472762   1257.7674877596644   1229.4822062265534  \
# 0   [-1977.2676153979373         -2048.734224         -2070.095089
# 1    [3859.0232159544416          3858.141824          3828.041338
# 2     [5051.813682795418          5103.505010          5090.018561
# 3    [-3737.688391049955         -3837.675226         -3830.275504
# 4     [4069.985197148189          4076.800014          4055.428374
# 5   [-4069.7881237666606         -4102.029247         -4127.774891
# 6    [3534.4538006003013          3507.555227          3510.146821
# 7   [-2213.2108894881057         -2238.164474         -2223.282141
# 8   [-4202.2762716467305         -4189.677491         -4177.031017
# 9   [-3638.9383219595984         -3627.175008         -3602.060247
# 10    [4091.011706836038          4079.259695          4052.086017
# 11   [4672.0562408658825          4677.476070          4657.672741
# 12  [-3686.8869525931864         -3687.723954         -3692.775315
# ...

# %%
v=[float(n.strip("[]")) if type(n)==str else n for n in df.iloc[0].values.tolist() ]
v
# Out:
# [-1977.2676153979373,
#  -2048.734224275406,
#  -2070.0950889094183,
#  -2123.794981082043,
#  -2172.588805909323,
#  -2225.1244248312896,
#  -2337.224132270064,
#  -2324.5229227379764,
#  -2201.582102428533,
#  -2106.2582654257526,
#  -2040.3670871668887,
#  -1994.5283151283725,
#  -1962.3430977612145,
#  -1939.446377517364,
#  -1922.860470681711,
#  -1910.5541049845303,
#  -1901.1416124224936,
#  -1893.6777304448256,
#  -1887.517623402049,
#  -1882.2213946902452,
#  -1877.4889486965044,
#  -1873.1155561843784,
#  -1868.9615427518331,
#  -1864.931611494452,
#  -1860.9607377460095,
#  -1857.00454703417,
#  -1853.0327513130323,
#  -1849.024671437576,
#  -1844.9661827987609,
#  -1840.8476317953728,
#  -1836.662414590915,
#  -1832.4060076823084,
#  -1828.0753067164424,
#  -1823.6681756393816,
#  -1819.1831394113829,
#  -1814.6191747817031,
#  -1809.9755681389663,
#  -1805.2518193861192,
#  -1800.4475776048794,
#  -1795.5625989822715,
#  -1790.5967207687077,
#  -1785.549847411163,
# ...

# %%
lol=[]
for i in range(59):
    lol.append([float(n.strip("[]")) if type(n)==str else n for n in df.iloc[i].values.tolist() ])
#    plt.plot(v)
 #   plt.show()

# %%
flat_list = [item for sublist in lol for item in sublist]

# %%
flat_list
# Out:
# [-1977.2676153979373,
#  -2048.734224275406,
#  -2070.0950889094183,
#  -2123.794981082043,
#  -2172.588805909323,
#  -2225.1244248312896,
#  -2337.224132270064,
#  -2324.5229227379764,
#  -2201.582102428533,
#  -2106.2582654257526,
#  -2040.3670871668887,
#  -1994.5283151283725,
#  -1962.3430977612145,
#  -1939.446377517364,
#  -1922.860470681711,
#  -1910.5541049845303,
#  -1901.1416124224936,
#  -1893.6777304448256,
#  -1887.517623402049,
#  -1882.2213946902452,
#  -1877.4889486965044,
#  -1873.1155561843784,
#  -1868.9615427518331,
#  -1864.931611494452,
#  -1860.9607377460095,
#  -1857.00454703417,
#  -1853.0327513130323,
#  -1849.024671437576,
#  -1844.9661827987609,
#  -1840.8476317953728,
#  -1836.662414590915,
#  -1832.4060076823084,
#  -1828.0753067164424,
#  -1823.6681756393816,
#  -1819.1831394113829,
#  -1814.6191747817031,
#  -1809.9755681389663,
#  -1805.2518193861192,
#  -1800.4475776048794,
#  -1795.5625989822715,
#  -1790.5967207687077,
#  -1785.549847411163,
# ...

# %%
plt.plot(flat_list[10000:20000])
print(sum([abs(x) for x in flat_list[10000:20000]]))
plt.show()
# Out:
# nan
